# %%
import numpy as np 
import random
import math
import matplotlib.pyplot as plt
  
# A custom function to calculate
# probability distribution function

def add_to_list():
    random_list = []
    for i in range(1,100):
        n = random.randint(1,100)
        random_list.append(n)
    #string = ', '.join([str(item) for item in random_list]) 
    
    return random_list

def find_avrg(list):
    total = 0
    for nums in list:
        total +=nums
    return math.trunc(total/len(list))

def run():
    avrg_map ={}
    for i in range(1,10000):
        x = find_avrg(add_to_list())
        if x not in avrg_map:
            avrg_map[x] = 1
        else:
            avrg_map[x] +=1
    return avrg_map

run()
# To generate an array of x-values
i =run()
sort_orders = sorted(i.items())
x_vals = []
y_vals = []

for i in sort_orders:
    x_vals.append(i[0])
    y_vals.append(i[1])
print(sort_orders)
x =x_vals
y = y_vals
  
# Plotting the bell-shaped curve
plt.style.use('seaborn')
plt.figure(figsize = (6, 6))
plt.plot(x_vals, y_vals, color = 'black',linestyle = 'dashed')
         
  
plt.scatter( x, y, marker = 'o', s = 25, color = 'red')
plt.show()
# Out:
# [(40, 4), (41, 10), (42, 40), (43, 73), (44, 153), (45, 323), (46, 500), (47, 820), (48, 1079), (49, 1288), (50, 1411), (51, 1234), (52, 1090), (53, 815), (54, 564), (55, 321), (56, 164), (57, 68), (58, 33), (59, 7), (60, 2)]
