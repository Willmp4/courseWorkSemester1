# %%
import numpy as np 
import random
import math
import matplotlib.pyplot as plt
  
# A custom function to calculate
# probability distribution function

def add_to_list():
    random_list = []
    for i in range(1,100):
        n = random.randint(1,100)
        random_list.append(n)
    #string = ', '.join([str(item) for item in random_list]) 
    
    return random_list

def find_avrg(list):
    total = 0
    for nums in list:
        total +=nums
    return round(total/len(list))


def run():
    avrg_map ={}
    num = int(input("Enter a range"))
    for i in range(1,num):
        x = find_avrg(add_to_list())
        if x not in avrg_map:
            avrg_map[x] = 1
        else:
            avrg_map[x] +=1
    return avrg_map
# To generate an array of x-values
i =run()
sort_orders = sorted(i.items())
x_vals = []
y_vals = []

for i in sort_orders:
    x_vals.append(i[0])
    y_vals.append(i[1])
print(sort_orders)
x =x_vals
y = y_vals
# Plotting the bell-shaped curve
plt.style.use('seaborn')
plt.figure(figsize = (6, 6))
plt.plot(x_vals, y_vals, color = 'black',linestyle = 'dashed')
         
  
plt.scatter( x, y, marker = 'o', s = 25, color = 'red')
plt.show()
# Out:
# [(36, 1), (38, 2), (39, 10), (40, 23), (41, 76), (42, 166), (43, 461), (44, 1190), (45, 2269), (46, 4016), (47, 6572), (48, 9429), (49, 11852), (50, 13625), (51, 13448), (52, 12030), (53, 9559), (54, 6673), (55, 4396), (56, 2331), (57, 1090), (58, 511), (59, 181), (60, 55), (61, 25), (62, 7), (63, 1)]
