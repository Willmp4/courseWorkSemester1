# %%
import numpy as np 
import random
import math
import matplotlib.pyplot as plt
  
# A custom function to calculate
# probability distribution function

def add_to_list():
    random_list = []
    for i in range(1,100):
        n = random.randint(1,100)
        random_list.append(n)
    #string = ', '.join([str(item) for item in random_list]) 
    
    return random_list

def find_avrg(list):
    total = 0
    for nums in list:
        total +=nums
    return round(total/len(list))


def run():
    avrg_map ={}
    num = int(input("Enter a range"))
    for i in range(1,num):
        x = find_avrg(add_to_list())
        if x not in avrg_map:
            avrg_map[x] = 1
        else:
            avrg_map[x] +=1
    return avrg_map
# To generate an array of x-values
i =run()
sort_orders = sorted(i.items())
x_vals = []
y_vals = []

for i in sort_orders:
    x_vals.append(i[0])
    y_vals.append(i[1])
print(sort_orders)
x =x_vals
y = y_vals
# Plotting the bell-shaped curve
plt.style.use('seaborn')
plt.figure(figsize = (6, 6))
plt.plot(x_vals, y_vals, color = 'black',linestyle = 'dashed')
         
  
plt.scatter( x, y, marker = 'o', s = 25, color = 'red')
plt.show()
# Out:
# [(40, 1), (41, 8), (42, 26), (43, 46), (44, 125), (45, 246), (46, 405), (47, 680), (48, 940), (49, 1185), (50, 1332), (51, 1350), (52, 1182), (53, 949), (54, 680), (55, 406), (56, 230), (57, 120), (58, 56), (59, 19), (60, 11), (62, 2)]
